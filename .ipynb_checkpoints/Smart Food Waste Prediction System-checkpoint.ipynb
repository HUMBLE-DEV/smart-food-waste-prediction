# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### DATA LOADING

# %%
df=pd.read_csv('food_waste_prediction_dataset_1000_rows.csv')
df.head()
# Out:
#   Day_of_Week  Festival Weather  Expected_Customers  Previous_Day_Consumption  \
# 0    Thursday         0  Cloudy                 572                       352
# 1      Sunday         0   Rainy                 486                       512
# 2   Wednesday         0   Sunny                 516                       385
# 3      Sunday         0   Rainy                 462                       460
# 4    Thursday         0  Cloudy                 402                       337
#
#    Previous_Week_Same_Day  Meals_Consumed
# 0                     361             512
# 1                     509             385
# 2                     390             460
# 3                     480             337
# 4                     327             316

# %%
df.shape
# Out:
# (1000, 7)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Day_of_Week               1000 non-null   object
#  1   Festival                  1000 non-null   int64
#  2   Weather                   1000 non-null   object
#  3   Expected_Customers        1000 non-null   int64
#  4   Previous_Day_Consumption  1000 non-null   int64
#  5   Previous_Week_Same_Day    1000 non-null   int64
#  6   Meals_Consumed            1000 non-null   int64
# dtypes: int64(5), object(2)
# memory usage: 54.8+ KB

# %%
df.describe()
# Out:
#           Festival  Expected_Customers  Previous_Day_Consumption  \
# count  1000.000000         1000.000000               1000.000000
# mean      0.103000          474.430000                396.360000
# std       0.304111           72.490012                 72.968917
# min       0.000000          350.000000                240.000000
# 25%       0.000000          412.000000                337.000000
# 50%       0.000000          474.000000                393.000000
# 75%       0.000000          535.250000                450.000000
# max       1.000000          600.000000                606.000000
#
#        Previous_Week_Same_Day  Meals_Consumed
# count             1000.000000     1000.000000
# mean               398.821000      396.483000
# std                 72.123344       72.997729
# min                300.000000      240.000000
# 25%                337.000000      337.000000
# 50%                392.500000      393.000000
# 75%                450.250000      450.250000
# max                660.000000      606.000000

# %%
df['Festival'].value_counts()
# Out:
# Festival
# 0    897
# 1    103
# Name: count, dtype: int64

# %%
df['Expected_Customers'].nunique()
# Out:
# 246

# %%
df.isnull().sum()
# Out:
# Day_of_Week                 0
# Festival                    0
# Weather                     0
# Expected_Customers          0
# Previous_Day_Consumption    0
# Previous_Week_Same_Day      0
# Meals_Consumed              0
# dtype: int64

# %% [markdown]
# ###  EXPLORATORY DATA ANALYSIS (EDA)

# %%
Av_food_spoid=sum(df['Expected_Customers'])/df.shape[0]-sum(df['Meals_Consumed'])/df.shape[0]
Av_food_spoid
# Out:
# 77.947

# %%
df['Expected_Customers'].value_counts(ascending=True)
# Out:
# Expected_Customers
# 551     1
# 475     1
# 497     1
# 472     1
# 416     1
#        ..
# 592     9
# 487     9
# 565     9
# 470    10
# 514    11
# Name: count, Length: 246, dtype: int64

# %%
sns.scatterplot(df, x='Expected_Customers', y='Meals_Consumed')
# Out:
# <Axes: xlabel='Expected_Customers', ylabel='Meals_Consumed'>

# %%
sns.barplot(x='Festival', y='Meals_Consumed', data=df)
plt.show()

# %%
sns.barplot(x="Weather",y='Meals_Consumed',data=df)
# Out:
# <Axes: xlabel='Weather', ylabel='Meals_Consumed'>

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.show()

# %%
df[['Meals_Consumed','Day_of_Week']].plot(kind="bar")
# Out:
# <Axes: >

# %% [markdown]
# ### DATA PREPROCESSING
